# %% [markdown]
# # Unsupervised Learning

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Load Dataset

# %%
data = load_iris()
X = pd.DataFrame(data.data, columns= data.feature_names)
X.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# ## Visualize Relationships

# %%
sns.pairplot(X)
plt.suptitle("Unsupervised Learning: Exploring Data Without Labels", y=1.02)
plt.show()
