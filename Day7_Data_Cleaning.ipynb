# %% [markdown]
# ## Data Cleaning and Handling Missing Values.

# %%
import pandas as pd

# %%
df = pd.read_csv("large_messy_dataset(Sheet1).csv")
df
# Out:
#     ID        Name     Age        City    Salary   Join_Date  \
# 0    1      George      40    Lalitpur  thousand  2021-01-10
# 1    2         Tom     NaN         NaN      NaN   2020-13-01
# 2    3        Isha     45          NaN     70000  2021-01-10
# 3    4         Oli     NaN                   55k  2021-01-10
# 4    5     George/     NaN     Birgunj     70000  2020-13-01
# 5    6       Nina_     NaN      Butwal  thousand  2020-13-01
# 6    7       David     45   Biratnagar      NaN   2020-15-10
# 7    8       /Mina      40         NaN     60000  2020-13-01
# 8    9       David      30         NaN       NaN  2020-13-01
# 9   10        Jake      25    Lalitpur     50000         NaN
# 10  11  Quincy_...      30         NaN     60000  2021/03/40
# 11  12      Paul//      35     Pokhara       NaN  2022/07/20
# 12  13        Nina      40      Butwal  thousand  2020-13-01
# 13  14   ...George      30  Biratnagar       55k  2020-13-01
# ...

# %% [markdown]
# ### Droping Data Duplicates

# %%
df= df.drop_duplicates()
df
# Out:
#     ID        Name     Age        City    Salary   Join_Date  \
# 0    1      George      40    Lalitpur  thousand  2021-01-10
# 1    2         Tom     NaN         NaN      NaN   2020-13-01
# 2    3        Isha     45          NaN     70000  2021-01-10
# 3    4         Oli     NaN                   55k  2021-01-10
# 4    5     George/     NaN     Birgunj     70000  2020-13-01
# 5    6       Nina_     NaN      Butwal  thousand  2020-13-01
# 6    7       David     45   Biratnagar      NaN   2020-15-10
# 7    8       /Mina      40         NaN     60000  2020-13-01
# 8    9       David      30         NaN       NaN  2020-13-01
# 9   10        Jake      25    Lalitpur     50000         NaN
# 10  11  Quincy_...      30         NaN     60000  2021/03/40
# 11  12      Paul//      35     Pokhara       NaN  2022/07/20
# 12  13        Nina      40      Butwal  thousand  2020-13-01
# 13  14   ...George      30  Biratnagar       55k  2020-13-01
# ...

# %% [markdown]
# ### Droping columns

# %%
df = df.drop(columns = "Non_ usable column")
df
# Out:
#     ID        Name     Age        City    Salary   Join_Date  \
# 0    1      George      40    Lalitpur  thousand  2021-01-10
# 1    2         Tom     NaN         NaN      NaN   2020-13-01
# 2    3        Isha     45          NaN     70000  2021-01-10
# 3    4         Oli     NaN                   55k  2021-01-10
# 4    5     George/     NaN     Birgunj     70000  2020-13-01
# 5    6       Nina_     NaN      Butwal  thousand  2020-13-01
# 6    7       David     45   Biratnagar      NaN   2020-15-10
# 7    8       /Mina      40         NaN     60000  2020-13-01
# 8    9       David      30         NaN       NaN  2020-13-01
# 9   10        Jake      25    Lalitpur     50000         NaN
# 10  11  Quincy_...      30         NaN     60000  2021/03/40
# 11  12      Paul//      35     Pokhara       NaN  2022/07/20
# 12  13        Nina      40      Butwal  thousand  2020-13-01
# 13  14   ...George      30  Biratnagar       55k  2020-13-01
# ...

# %% [markdown]
# ### Strip

# %%
#(note: lstrip: Remove unwanted from left side, rstrip: Remove unwanted from right side, strip: reomove unwanted from both side)
df["Name"].str.lstrip("/") #It remove / from left of Name column
# Out:
# 0         George
# 1            Tom
# 2           Isha
# 3            Oli
# 4        George/
# 5          Nina_
# 6          David
# 7           Mina
# 8          David
# 9           Jake
# 10    Quincy_...
# 11        Paul//
# 12          Nina
# 13     ...George
# 14          Isha
# 15         Frank
# 16           Eve
# 17         Alice
# 18        _Frank
# 19          Isha
# 20          Nina
# 21         Frank
# 22           Eve
# 23          Mina
# 24          Nina
# 25        Quincy
# 26          Ravi
# 27          Isha
# 28         Frank
# 29          Paul
# 30          Jake
# 31         Frank
# 32          Hira
# 33        George
# 34          Isha
# 35          Isha
# 36          Jake
# 37           Bob
# 38          Mina
# 39        Quincy
# 40        Quincy
# 41         David
# 42         Frank
# 43           Tom
# 44         Alice
# 45         Kiran
# 46          Ravi
# 47           Tom
# 48           Tom
# 49           Sam
# Name: Name, dtype: object

# %%
df["Name"].str.rstrip("...") #It remove ... from right of Name column
# Out:
# 0        George
# 1           Tom
# 2          Isha
# 3           Oli
# 4       George/
# 5         Nina_
# 6         David
# 7         /Mina
# 8         David
# 9          Jake
# 10      Quincy_
# 11       Paul//
# 12         Nina
# 13    ...George
# 14         Isha
# 15        Frank
# 16          Eve
# 17        Alice
# 18       _Frank
# 19         Isha
# 20         Nina
# 21        Frank
# 22          Eve
# 23         Mina
# 24         Nina
# 25       Quincy
# 26         Ravi
# 27         Isha
# 28        Frank
# 29         Paul
# 30         Jake
# 31        Frank
# 32         Hira
# 33       George
# 34         Isha
# 35         Isha
# 36         Jake
# 37          Bob
# 38         Mina
# 39       Quincy
# 40       Quincy
# 41        David
# 42        Frank
# 43          Tom
# 44        Alice
# 45        Kiran
# 46         Ravi
# 47          Tom
# 48          Tom
# 49          Sam
# Name: Name, dtype: object

# %%
df["Name"].str.strip("_")#It roemove _from both side
# Out:
# 0         George
# 1            Tom
# 2           Isha
# 3            Oli
# 4        George/
# 5           Nina
# 6          David
# 7          /Mina
# 8          David
# 9           Jake
# 10    Quincy_...
# 11        Paul//
# 12          Nina
# 13     ...George
# 14          Isha
# 15         Frank
# 16           Eve
# 17         Alice
# 18         Frank
# 19          Isha
# 20          Nina
# 21         Frank
# 22           Eve
# 23          Mina
# 24          Nina
# 25        Quincy
# 26          Ravi
# 27          Isha
# 28         Frank
# 29          Paul
# 30          Jake
# 31         Frank
# 32          Hira
# 33        George
# 34          Isha
# 35          Isha
# 36          Jake
# 37           Bob
# 38          Mina
# 39        Quincy
# 40        Quincy
# 41         David
# 42         Frank
# 43           Tom
# 44         Alice
# 45         Kiran
# 46          Ravi
# 47           Tom
# 48           Tom
# 49           Sam
# Name: Name, dtype: object

# %%
df["Name"]= df["Name"].str.strip("123._/") #It remove the numbers, ., _, / from the Name column
df
# Out:
#     ID    Name     Age        City    Salary   Join_Date              Email  \
# 0    1  George      40    Lalitpur  thousand  2021-01-10          bob@gmail
# 1    2     Tom     NaN         NaN      NaN   2020-13-01     luna@gmail.com
# 2    3    Isha     45          NaN     70000  2021-01-10          Luna@mail
# 3    4     Oli     NaN                   55k  2021-01-10          Nina@mail
# 4    5  George     NaN     Birgunj     70000  2020-13-01          Jake@mail
# 5    6    Nina     NaN      Butwal  thousand  2020-13-01           Eve@mail
# 6    7   David     45   Biratnagar      NaN   2020-15-10     david@mail.com
# 7    8    Mina      40         NaN     60000  2020-13-01   quincy@gmail.com
# 8    9   David      30         NaN       NaN  2020-13-01                NaN
# 9   10    Jake      25    Lalitpur     50000         NaN         David@mail
# 10  11  Quincy      30         NaN     60000  2021/03/40           Tom@mail
# ...

# %% [markdown]
# ### Cleaning / Standardizing phone numbers

# %%
#I wants all the phone numbers in 111-111-1111 this format 
#df["Phone_number"].apply(lambda x: str(x))
#df["Phone_number"].apply(lambda)

# %%
df["Phone_number"] = df["Phone_number"].str.replace(r'[^0-9]', '', regex=True)
df
# Out:
#     ID    Name     Age        City    Salary   Join_Date              Email  \
# 0    1  George      40    Lalitpur  thousand  2021-01-10          bob@gmail
# 1    2     Tom     NaN         NaN      NaN   2020-13-01     luna@gmail.com
# 2    3    Isha     45          NaN     70000  2021-01-10          Luna@mail
# 3    4     Oli     NaN                   55k  2021-01-10          Nina@mail
# 4    5  George     NaN     Birgunj     70000  2020-13-01          Jake@mail
# 5    6    Nina     NaN      Butwal  thousand  2020-13-01           Eve@mail
# 6    7   David     45   Biratnagar      NaN   2020-15-10     david@mail.com
# 7    8    Mina      40         NaN     60000  2020-13-01   quincy@gmail.com
# 8    9   David      30         NaN       NaN  2020-13-01                NaN
# 9   10    Jake      25    Lalitpur     50000         NaN         David@mail
# 10  11  Quincy      30         NaN     60000  2021/03/40           Tom@mail
# ...

# %%
df["Phone_number"]=df["Phone_number"].apply(lambda x: str(x))
df
# Out:
#     ID    Name     Age        City    Salary   Join_Date              Email  \
# 0    1  George      40    Lalitpur  thousand  2021-01-10          bob@gmail
# 1    2     Tom     NaN         NaN      NaN   2020-13-01     luna@gmail.com
# 2    3    Isha     45          NaN     70000  2021-01-10          Luna@mail
# 3    4     Oli     NaN                   55k  2021-01-10          Nina@mail
# 4    5  George     NaN     Birgunj     70000  2020-13-01          Jake@mail
# 5    6    Nina     NaN      Butwal  thousand  2020-13-01           Eve@mail
# 6    7   David     45   Biratnagar      NaN   2020-15-10     david@mail.com
# 7    8    Mina      40         NaN     60000  2020-13-01   quincy@gmail.com
# 8    9   David      30         NaN       NaN  2020-13-01                NaN
# 9   10    Jake      25    Lalitpur     50000         NaN         David@mail
# 10  11  Quincy      30         NaN     60000  2021/03/40           Tom@mail
# ...

# %%
df["Phone_number"]=df["Phone_number"].apply(lambda x: x[0:3]+'-'+x[3:6]+'-'+x[6:10])
df
# Out:
#     ID    Name     Age        City    Salary   Join_Date              Email  \
# 0    1  George      40    Lalitpur  thousand  2021-01-10          bob@gmail
# 1    2     Tom     NaN         NaN      NaN   2020-13-01     luna@gmail.com
# 2    3    Isha     45          NaN     70000  2021-01-10          Luna@mail
# 3    4     Oli     NaN                   55k  2021-01-10          Nina@mail
# 4    5  George     NaN     Birgunj     70000  2020-13-01          Jake@mail
# 5    6    Nina     NaN      Butwal  thousand  2020-13-01           Eve@mail
# 6    7   David     45   Biratnagar      NaN   2020-15-10     david@mail.com
# 7    8    Mina      40         NaN     60000  2020-13-01   quincy@gmail.com
# 8    9   David      30         NaN       NaN  2020-13-01                NaN
# 9   10    Jake      25    Lalitpur     50000         NaN         David@mail
# 10  11  Quincy      30         NaN     60000  2021/03/40           Tom@mail
# ...

# %%
df["Phone_number"]=df["Phone_number"].replace('nan--','')
df
# Out:
#     ID    Name     Age        City    Salary   Join_Date              Email  \
# 0    1  George      40    Lalitpur  thousand  2021-01-10          bob@gmail
# 1    2     Tom     NaN         NaN      NaN   2020-13-01     luna@gmail.com
# 2    3    Isha     45          NaN     70000  2021-01-10          Luna@mail
# 3    4     Oli     NaN                   55k  2021-01-10          Nina@mail
# 4    5  George     NaN     Birgunj     70000  2020-13-01          Jake@mail
# 5    6    Nina     NaN      Butwal  thousand  2020-13-01           Eve@mail
# 6    7   David     45   Biratnagar      NaN   2020-15-10     david@mail.com
# 7    8    Mina      40         NaN     60000  2020-13-01   quincy@gmail.com
# 8    9   David      30         NaN       NaN  2020-13-01                NaN
# 9   10    Jake      25    Lalitpur     50000         NaN         David@mail
# 10  11  Quincy      30         NaN     60000  2021/03/40           Tom@mail
# ...

# %%
df["Department"]=df["Department"].apply(lambda x: str(x))
df
# Out:
#     ID    Name     Age        City    Salary   Join_Date              Email  \
# 0    1  George      40    Lalitpur  thousand  2021-01-10          bob@gmail
# 1    2     Tom     NaN         NaN      NaN   2020-13-01     luna@gmail.com
# 2    3    Isha     45          NaN     70000  2021-01-10          Luna@mail
# 3    4     Oli     NaN                   55k  2021-01-10          Nina@mail
# 4    5  George     NaN     Birgunj     70000  2020-13-01          Jake@mail
# 5    6    Nina     NaN      Butwal  thousand  2020-13-01           Eve@mail
# 6    7   David     45   Biratnagar      NaN   2020-15-10     david@mail.com
# 7    8    Mina      40         NaN     60000  2020-13-01   quincy@gmail.com
# 8    9   David      30         NaN       NaN  2020-13-01                NaN
# 9   10    Jake      25    Lalitpur     50000         NaN         David@mail
# 10  11  Quincy      30         NaN     60000  2021/03/40           Tom@mail
# ...

# %%
df["Department"]=df["Department"].replace('nan','')
df
# Out:
#     ID    Name     Age        City    Salary   Join_Date              Email  \
# 0    1  George      40    Lalitpur  thousand  2021-01-10          bob@gmail
# 1    2     Tom     NaN         NaN      NaN   2020-13-01     luna@gmail.com
# 2    3    Isha     45          NaN     70000  2021-01-10          Luna@mail
# 3    4     Oli     NaN                   55k  2021-01-10          Nina@mail
# 4    5  George     NaN     Birgunj     70000  2020-13-01          Jake@mail
# 5    6    Nina     NaN      Butwal  thousand  2020-13-01           Eve@mail
# 6    7   David     45   Biratnagar      NaN   2020-15-10     david@mail.com
# 7    8    Mina      40         NaN     60000  2020-13-01   quincy@gmail.com
# 8    9   David      30         NaN       NaN  2020-13-01                NaN
# 9   10    Jake      25    Lalitpur     50000         NaN         David@mail
# 10  11  Quincy      30         NaN     60000  2021/03/40           Tom@mail
# ...

# %%
df["Age"]=df["Age"].apply(lambda x: str(x))
df
# Out:
#     ID    Name     Age        City    Salary   Join_Date              Email  \
# 0    1  George      40    Lalitpur  thousand  2021-01-10          bob@gmail
# 1    2     Tom     nan         NaN      NaN   2020-13-01     luna@gmail.com
# 2    3    Isha     45          NaN     70000  2021-01-10          Luna@mail
# 3    4     Oli     nan                   55k  2021-01-10          Nina@mail
# 4    5  George     nan     Birgunj     70000  2020-13-01          Jake@mail
# 5    6    Nina     nan      Butwal  thousand  2020-13-01           Eve@mail
# 6    7   David     45   Biratnagar      NaN   2020-15-10     david@mail.com
# 7    8    Mina      40         NaN     60000  2020-13-01   quincy@gmail.com
# 8    9   David      30         NaN       NaN  2020-13-01                NaN
# 9   10    Jake      25    Lalitpur     50000         NaN         David@mail
# 10  11  Quincy      30         NaN     60000  2021/03/40           Tom@mail
# ...

# %%
df["Age"]=df["Age"].replace('nan','')
df
# Out:
#     ID    Name     Age        City    Salary   Join_Date              Email  \
# 0    1  George      40    Lalitpur  thousand  2021-01-10          bob@gmail
# 1    2     Tom                 NaN      NaN   2020-13-01     luna@gmail.com
# 2    3    Isha     45          NaN     70000  2021-01-10          Luna@mail
# 3    4     Oli                           55k  2021-01-10          Nina@mail
# 4    5  George             Birgunj     70000  2020-13-01          Jake@mail
# 5    6    Nina              Butwal  thousand  2020-13-01           Eve@mail
# 6    7   David     45   Biratnagar      NaN   2020-15-10     david@mail.com
# 7    8    Mina      40         NaN     60000  2020-13-01   quincy@gmail.com
# 8    9   David      30         NaN       NaN  2020-13-01                NaN
# 9   10    Jake      25    Lalitpur     50000         NaN         David@mail
# 10  11  Quincy      30         NaN     60000  2021/03/40           Tom@mail
# ...

# %%
df["City"]=df["City"].apply(lambda x: str(x))
df
# Out:
#     ID    Name     Age        City    Salary   Join_Date              Email  \
# 0    1  George      40    Lalitpur  thousand  2021-01-10          bob@gmail
# 1    2     Tom                 nan      NaN   2020-13-01     luna@gmail.com
# 2    3    Isha     45          nan     70000  2021-01-10          Luna@mail
# 3    4     Oli                           55k  2021-01-10          Nina@mail
# 4    5  George             Birgunj     70000  2020-13-01          Jake@mail
# 5    6    Nina              Butwal  thousand  2020-13-01           Eve@mail
# 6    7   David     45   Biratnagar      NaN   2020-15-10     david@mail.com
# 7    8    Mina      40         nan     60000  2020-13-01   quincy@gmail.com
# 8    9   David      30         nan       NaN  2020-13-01                NaN
# 9   10    Jake      25    Lalitpur     50000         NaN         David@mail
# 10  11  Quincy      30         nan     60000  2021/03/40           Tom@mail
# ...

# %%
df["City"]=df["City"].replace('nan','')
df
# Out:
#     ID    Name     Age        City    Salary   Join_Date              Email  \
# 0    1  George      40    Lalitpur  thousand  2021-01-10          bob@gmail
# 1    2     Tom                          NaN   2020-13-01     luna@gmail.com
# 2    3    Isha     45                  70000  2021-01-10          Luna@mail
# 3    4     Oli                           55k  2021-01-10          Nina@mail
# 4    5  George             Birgunj     70000  2020-13-01          Jake@mail
# 5    6    Nina              Butwal  thousand  2020-13-01           Eve@mail
# 6    7   David     45   Biratnagar      NaN   2020-15-10     david@mail.com
# 7    8    Mina      40                 60000  2020-13-01   quincy@gmail.com
# 8    9   David      30                   NaN  2020-13-01                NaN
# 9   10    Jake      25    Lalitpur     50000         NaN         David@mail
# 10  11  Quincy      30                 60000  2021/03/40           Tom@mail
# ...

# %%
df["Salary"]=df["Salary"].apply(lambda x: str(x))
df
# Out:
#     ID    Name     Age        City    Salary   Join_Date              Email  \
# 0    1  George      40    Lalitpur  thousand  2021-01-10          bob@gmail
# 1    2     Tom                          NaN   2020-13-01     luna@gmail.com
# 2    3    Isha     45                  70000  2021-01-10          Luna@mail
# 3    4     Oli                           55k  2021-01-10          Nina@mail
# 4    5  George             Birgunj     70000  2020-13-01          Jake@mail
# 5    6    Nina              Butwal  thousand  2020-13-01           Eve@mail
# 6    7   David     45   Biratnagar      NaN   2020-15-10     david@mail.com
# 7    8    Mina      40                 60000  2020-13-01   quincy@gmail.com
# 8    9   David      30                   nan  2020-13-01                NaN
# 9   10    Jake      25    Lalitpur     50000         NaN         David@mail
# 10  11  Quincy      30                 60000  2021/03/40           Tom@mail
# ...

# %%
df["Salary"]=df["Salary"].replace('nan','')
df
# Out:
#     ID    Name     Age        City    Salary   Join_Date              Email  \
# 0    1  George      40    Lalitpur  thousand  2021-01-10          bob@gmail
# 1    2     Tom                          NaN   2020-13-01     luna@gmail.com
# 2    3    Isha     45                  70000  2021-01-10          Luna@mail
# 3    4     Oli                           55k  2021-01-10          Nina@mail
# 4    5  George             Birgunj     70000  2020-13-01          Jake@mail
# 5    6    Nina              Butwal  thousand  2020-13-01           Eve@mail
# 6    7   David     45   Biratnagar      NaN   2020-15-10     david@mail.com
# 7    8    Mina      40                 60000  2020-13-01   quincy@gmail.com
# 8    9   David      30                        2020-13-01                NaN
# 9   10    Jake      25    Lalitpur     50000         NaN         David@mail
# 10  11  Quincy      30                 60000  2021/03/40           Tom@mail
# ...

# %%
df["Salary"]=df["Salary"].replace('thousand','1000')
df["Salary"]=df["Salary"].replace('55k','55000')
df
# Out:
#     ID    Name     Age        City Salary              Email Department  \
# 0    1  George      40    Lalitpur   1000      bob@gmail.com
# 1    2     Tom                       NaN      luna@gmail.com      Sales
# 2    3    Isha     45               70000      luna@mail.com
# 3    4     Oli                      55000      nina@mail.com         HR
# 4    5  George             Birgunj  70000      jake@mail.com    Finance
# 5    6    Nina              Butwal   1000       eve@mail.com      Sales
# 6    7   David     45   Biratnagar   NaN      david@mail.com         HR
# 7    8    Mina      40              60000   quincy@gmail.com         IT
# 8    9   David      30                             na@na.com      Sales
# 9   10    Jake      25    Lalitpur  50000     david@mail.com         IT
# 10  11  Quincy      30              60000       tom@mail.com         IT
# 11  12    Paul      35     Pokhara                 na@na.com    Finance
# ...

# %%
df["Email"]=df["Email"].apply(lambda x: str(x))
df
# Out:
#     ID    Name     Age        City Salary              Email Department  \
# 0    1  George      40    Lalitpur   1000      bob@gmail.com
# 1    2     Tom                       NaN      luna@gmail.com      Sales
# 2    3    Isha     45               70000      luna@mail.com
# 3    4     Oli                      55000      nina@mail.com         HR
# 4    5  George             Birgunj  70000      jake@mail.com    Finance
# 5    6    Nina              Butwal   1000       eve@mail.com      Sales
# 6    7   David     45   Biratnagar   NaN      david@mail.com         HR
# 7    8    Mina      40              60000   quincy@gmail.com         IT
# 8    9   David      30                             na@na.com      Sales
# 9   10    Jake      25    Lalitpur  50000     david@mail.com         IT
# 10  11  Quincy      30              60000       tom@mail.com         IT
# 11  12    Paul      35     Pokhara                 na@na.com    Finance
# ...

# %%
df["Email"]=df["Email"].replace('nan','')
df
# Out:
#     ID    Name     Age        City Salary              Email Department  \
# 0    1  George      40    Lalitpur   1000      bob@gmail.com
# 1    2     Tom                       NaN      luna@gmail.com      Sales
# 2    3    Isha     45               70000      luna@mail.com
# 3    4     Oli                      55000      nina@mail.com         HR
# 4    5  George             Birgunj  70000      jake@mail.com    Finance
# 5    6    Nina              Butwal   1000       eve@mail.com      Sales
# 6    7   David     45   Biratnagar   NaN      david@mail.com         HR
# 7    8    Mina      40              60000   quincy@gmail.com         IT
# 8    9   David      30                             na@na.com      Sales
# 9   10    Jake      25    Lalitpur  50000     david@mail.com         IT
# 10  11  Quincy      30              60000       tom@mail.com         IT
# 11  12    Paul      35     Pokhara                 na@na.com    Finance
# ...

# %%
import re
def clean_email(email):
    email = str(email).strip().lower()     # remove spaces + lowercase
    # Split user and domain
    user, domain = email.split("@")[0], email.split("@")[-1]
    # Remove unwanted characters
    user = re.sub(r'[^a-z0-9._]', '', user)
    domain = re.sub(r'[^a-z0-9.]', '', domain)
    # If domain missing extension, add ".com"
    if "." not in domain:
        domain = domain + ".com"
    return user + "@" + domain

# %%
df["Email"] = df["Email"].apply(clean_email)
df
# Out:
#     ID    Name     Age        City Salary              Email Department  \
# 0    1  George      40    Lalitpur   1000      bob@gmail.com
# 1    2     Tom                       NaN      luna@gmail.com      Sales
# 2    3    Isha     45               70000      luna@mail.com
# 3    4     Oli                      55000      nina@mail.com         HR
# 4    5  George             Birgunj  70000      jake@mail.com    Finance
# 5    6    Nina              Butwal   1000       eve@mail.com      Sales
# 6    7   David     45   Biratnagar   NaN      david@mail.com         HR
# 7    8    Mina      40              60000   quincy@gmail.com         IT
# 8    9   David      30                             na@na.com      Sales
# 9   10    Jake      25    Lalitpur  50000     david@mail.com         IT
# 10  11  Quincy      30              60000       tom@mail.com         IT
# 11  12    Paul      35     Pokhara                 na@na.com    Finance
# ...
