# %%
#Lists

# %%
l1= [1, "Stranger Things", 3.14, True, 3+5j]

# %%
l1
# Out:
# [1, 'Stranger Things', 3.14, True, (3+5j)]

# %%
type(l1)
# Out:
# list

# %%
#Extracting individual elements

# %%
l1[0] #To extract first elements we need index 0
# Out:
# 1

# %%
l1[3]#It will extract the fourth elements of our list
# Out:
# True

# %%
l1[2:4] #For extract sequence of elments( it include starting index and exclude ending index)
# Out:
# [3.14, True]

# %%
l1[-1] #TO extract the last elements
# Out:
# (3+5j)

# %%
l1[0]=100#Change the zeroth index element
l1
# Out:
# [100, 'Stranger Things', 3.14, True, (3+5j)]

# %%
l1.append("Hello WOrld.")
l1
# Out:
# [100, 'Stranger Things', 3.14, True, (3+5j), 'Hello WOrld.']

# %%
l1.pop()#Pop out the last element of list
l1
# Out:
# [100, 'Stranger Things', 3.14, True, (3+5j)]

# %%
l1.reverse()#Reversing elements of list
l1
# Out:
# [(3+5j), True, 3.14, 'Stranger Things', 100]

# %%
l1.insert(1,"a")#Inserting element at index 1
l1
# Out:
# ['apple', 'a', 'banana', 'guava', 'mango']

# %%
l1=["mango", "banana","guava","apple"]
l1.sort()#sorting list
l1
# Out:
# ['apple', 'banana', 'guava', 'mango']

# %%
l2=["Avocado", "Blueberry", "Kiwi", "Orange"]
l1+l2#concatenating list l1 and l2
# Out:
# ['apple', 'banana', 'guava', 'mango', 'Avocado', 'Blueberry', 'Kiwi', 'Orange']

# %%
t1=("mango", "banana","apple")
t2=("guava","cherry")
t1+t2 #Concatenating tuple
# Out:
# ('mango', 'banana', 'apple', 'guava', 'cherry')

# %%
#Extracting individual element
t1[0] #Extracting zeroth  index element of t1 tuple
# Out:
# 'mango'

# %%
t2[1] #Extracting 1st index element of t2 tuple
# Out:
# 'cherry'

# %%
t1[1:3] #Extracing sequence of element of tuple
# Out:
# ('banana', 'apple')

# %%
#Dictionary in python
items={"Fruits":100,"Milk":60,"Meat":200,"Vegetables":50} #keys:value
items.keys()#Extracting keys
# Out:
# dict_keys(['Fruits', 'Milk', 'Meat', 'Vegetables'])

# %%
items.values() #Extracting values
# Out:
# dict_values([100, 60, 200, 50])

# %%
items["Bread"]=30 #Adding a new elements
items
# Out:
# {'Fruits': 100, 'Milk': 60, 'Meat': 200, 'Vegetables': 50, 'Bread': 30}

# %%
items["Fruits"]=110 #Changing an existing elements
items
# Out:
# {'Fruits': 110, 'Milk': 60, 'Meat': 200, 'Vegetables': 50, 'Bread': 30}

# %%
items1={"Medicine":150, "Toothbrush":200}
items.update(items1) #update one dictionary's elements with another
items
# Out:
# {'Fruits': 110,
#  'Milk': 60,
#  'Meat': 200,
#  'Vegetables': 50,
#  'Bread': 30,
#  'Medicine': 150,
#  'Toothbrush': 200}

# %%
items.pop("Toothbrush") #Poping out an element of Dictionary
items
# Out:
# {'Fruits': 110,
#  'Milk': 60,
#  'Meat': 200,
#  'Vegetables': 50,
#  'Bread': 30,
#  'Medicine': 150}

# %%
#Sets in python
s1={1, "a",True, "a","b",2} #Set is unindexed and unordered with unique elements
s1
# Out:
# {1, 2, 'a', 'b'}

# %%
s1.add("Hello") #Adding new elements
s1
# Out:
# {1, 2, 'Hello', 'a', 'b'}

# %%
s1.update([10,20,30]) #Updating multiple elements
s1
# Out:
# {1, 10, 2, 20, 30, 'Hello', 'a', 'b'}

# %%
s1.remove("b")#Removing an element
s1
# Out:
# {1, 10, 2, 20, 30, 'Hello', 'a'}

# %%
s2={"I'm","Kabindra",12} 
s1.union(s2)#Union of s1 and s2
# Out:
# {1, 10, 12, 2, 20, 30, 'Hello', "I'm", 'Kabindra', 'a'}

# %%
s1={1,2,3,4,5,6}
s2={5,6,7,8,9}
s1.intersection(s2)#intersection of two sets
# Out:
# {5, 6}
