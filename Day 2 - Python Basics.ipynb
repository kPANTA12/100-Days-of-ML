# %%
print("Hello! everyone") #First python program
# Out:
# Hello! everyone

# %%
#variables and datatype in python(Example for dynamically typed programming)
student_name="Kabindra Panta"#string
type(student_name)
# Out:
# 'Kabindra Panta'

# %%
student_name=10#integer
type(student_name)
# Out:
# int

# %%
student_name=10.1#float 
type(student_name)
# Out:
# 10.1

# %%
student_name=True#boolean
type(student_name)
# Out:
# bool

# %%
#Operators in python
#Arithmetic Operator(+, -, /, *)
a=5
b=10

# %%
a+b
# Out:
# 25

# %%
a-b
# Out:
# 5

# %%
a*b
# Out:
# 150

# %%
a/b
# Out:
# 1.5

# %%
#Relational operator(>, <,==,!=)
a>b
# Out:
# True

# %%
a<b
# Out:
# False

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
#Logical operator(&, |)
a=True
b=False
a&b
# Out:
# False

# %%
a&a
# Out:
# True

# %%
b&b
# Out:
# False

# %%
a|b
# Out:
# True

# %%
b|b
# Out:
# False
