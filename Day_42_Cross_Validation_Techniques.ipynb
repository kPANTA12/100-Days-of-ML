# %% [markdown]
# # Cross Validation Techniques

# %% [markdown]
# #### 1. Simple K-Fold Cross Validation

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LogisticRegression
X, y =load_iris(return_X_y=True)
model =LogisticRegression(max_iter=200)
kf=KFold(n_splits=5, shuffle = True, random_state=40)
scores=cross_val_score(model, X, y, cv=kf)
print("Scores for each fold:", scores)
print("Average accuracy:", scores.mean())
# Out:
# Scores for each fold: [1.         0.96666667 0.96666667 0.93333333 0.93333333]
# Average accuracy: 0.9600000000000002

# %% [markdown]
# #### 2. Stratified K-Fold

# %%
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
scores = cross_val_score(model, X, y, cv=skf)
print("Stratified scores:", scores)
print("Mean accuracy:", scores.mean())
# Out:
# Stratified scores: [1.         0.96666667 0.93333333 1.         0.93333333]
# Mean accuracy: 0.9666666666666668

# %% [markdown]
# #### 3. Compare Models Using CV

# %%
from sklearn.svm import SVC
models = {
    "Logistic Regression": LogisticRegression(max_iter=200),
    "SVM": SVC()
}
for name, model in models.items():
    scores = cross_val_score(model, X, y, cv=5)
    print(f"{name} → Mean Accuracy: {scores.mean():.3f}")
# Out:
# Logistic Regression → Mean Accuracy: 0.973
# SVM → Mean Accuracy: 0.967

# %% [markdown]
# #### 3. Effect of Different K Values

# %%
for k in [3, 5, 10]:
    scores = cross_val_score(model, X, y, cv=k)
    print(f"K={k} → Avg Accuracy: {scores.mean():.3f}")
# Out:
# K=3 → Avg Accuracy: 0.960
# K=5 → Avg Accuracy: 0.967
# K=10 → Avg Accuracy: 0.973
